# %% [markdown]
# <a href="https://colab.research.google.com/github/livialenda/tipos-de-dados-py-3F/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#revisão de variaveis e tipos de dados
#tipos de dados

#int: numeros inteiros (sem casas decimais)
idade = 17

#float: ponto flutuante (com casas decimais)
altura = 1.80

#string: (ou str) texto puro
nome = "Livia Trindade Da Silva"

#bool: boleano (sim, não, verdade, mentira, true, false)
estudante = True

#tipos de coleção
#listão coleção ordenada
frutas = ["maça", "banana", "uva", "pera"]

#tupla geralmente usada usada para guardar coordenadas
cianorte = (-23.6631, -52.6054)

#set (conjunto de dados nao repetitivos)
numeros = {1,2,3,4,5}

#dic (dicionario)
pessoa = {"nome": "Abner", "idade": 17}

#none type, quando preciso que algo
#"seja realmente nulo"
valor = None
